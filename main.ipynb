# %%
import pandas as pd

source = "/Users/andreyzhabrovets/Documents/GitHub/Hackathon_Thurgau_LABL/data/Energiereporter/energyreporter_municipality_latest.csv"

# CSV-Daten mit Pandas lesen.
# Achtung: wir verwenden Semikolons statt Kommas als Trennzeichen.
# header=0 teilt der Funktion mit, dass wir Spaltenheader in der Datei erwarten.
energy_dataset = pd.read_table(source, sep=';', header=0)
# Wie sehen die Daten aus?
energy_dataset
# Out:
#     bfs_nr  municipality canton  electric_car_share  \
# 0     4401         Arbon     TG            0.018812
# 1     4406        Dozwil     TG            0.029598
# 2     4411        Egnach     TG            0.020118
# 3     4416    Hefenhofen     TG            0.012427
# 4     4421          Horn     TG            0.021995
# ..     ...           ...    ...                 ...
# 75    4911  Bürglen (TG)     TG            0.020697
# 76    4921      Bussnang     TG            0.027716
# 77    4941    Märstetten     TG            0.023423
# 78    4946    Weinfelden     TG            0.032689
# 79    4951   Wigoltingen     TG            0.032593
#
#    electric_car_share_last_change  solar_potential_usage  \
# 0                      31.01.2023               0.070099
# 1                      31.01.2023               0.082002
# 2                      31.01.2023               0.107423
# 3                      31.01.2023               0.124892
# 4                      31.01.2023               0.161442
# ..                            ...                    ...
# 75                     31.01.2023               0.054989
# 76                     31.01.2023               0.066848
# 77                     31.01.2023               0.085916
# 78                     31.01.2023               0.134195
# 79                     31.01.2023               0.097926
#
#    solar_potential_usage_last_change  renewable_heating_share  \
# 0                         11.11.2022                 0.279190
# 1                         13.09.2022                 0.504902
# 2                         02.11.2022                 0.392504
# 3                         22.11.2022                 0.410798
# 4                         13.07.2022                 0.189011
# ..                               ...                      ...
# 75                        22.09.2022                 0.278761
# 76                        02.11.2022                 0.492000
# 77                        06.12.2022                 0.313299
# 78                        30.11.2022                 0.227486
# 79                        19.10.2022                 0.374846
#
#     renewable_heating_share_coverage renewable_heating_share_last_change
# 0                           0.879841                          22.02.2023
# 1                           0.883382                          28.10.2022
# 2                           0.856235                          06.02.2023
# 3                           0.812089                          10.01.2023
# 4                           0.811034                          17.08.2022
# ..                               ...                                 ...
# 75                          0.837147                          13.01.2023
# 76                          0.842365                          22.12.2022
# 77                          0.855214                          17.01.2023
# 78                          0.865462                          20.02.2023
# 79                          0.849834                          18.10.2022
#
# [80 rows x 10 columns]

# %%
import geopandas as gpd
municipalities = gpd.read_file("/Users/andreyzhabrovets/Documents/GitHub/Hackathon_Thurgau_LABL/data/GEO/towns_fixed.geojson")
municipalities
# Out:
#       bfs_nr country      type                   name  \
# 0       3762      CH  Gemeinde                  Scuol
# 1       3575      CH  Gemeinde                   Laax
# 2       5529      CH  Gemeinde  Oulens-sous-Echallens
# 3       3316      CH  Gemeinde                 Weesen
# 4        906      CH  Gemeinde              Schangnau
# ...      ...     ...       ...                    ...
# 2317    2305      CH    Bezirk                 Hérens
# 2318    4181      CH  Gemeinde                Wittnau
# 2319    5761      CH  Gemeinde      Romainmôtier-Envy
# 2320     442      CH  Gemeinde            Romont (BE)
# 2321    2788      CH  Gemeinde               Liesberg
#
#                                                geometry
# 0     MULTIPOLYGON (((1139077.532 5921141.517, 11400...
# 1     MULTIPOLYGON (((1025590.950 5924456.089, 10256...
# 2     MULTIPOLYGON (((732842.653 5882076.703, 732766...
# 3     MULTIPOLYGON (((1009859.085 5963319.102, 10098...
# 4     MULTIPOLYGON (((885081.295 5909434.189, 885096...
# ...                                                 ...
# 2317  MULTIPOLYGON (((820225.037 5808928.463, 820415...
# 2318  MULTIPOLYGON (((889975.343 6021115.485, 889971...
# 2319  MULTIPOLYGON (((721847.754 5888985.938, 721852...
# 2320  MULTIPOLYGON (((814775.095 5977288.045, 814849...
# 2321  MULTIPOLYGON (((827919.732 6004468.532, 827840...
#
# [2322 rows x 5 columns]

# %%
import pandas as pd
joined = pd.merge(municipalities, energy_dataset, how="inner", on="bfs_nr")
joined.head()
# Out:
#    bfs_nr country      type        name  \
# 0    4651      CH  Gemeinde  Gottlieben
# 1    4851      CH  Gemeinde  Salenstein
# 2    4741      CH  Gemeinde      Lommis
# 3    4696      CH  Gemeinde  Tägerwilen
# 4    4506      CH  Gemeinde      Sulgen
#
#                                             geometry municipality canton  \
# 0  MULTIPOLYGON (((1015394.782 6051105.977, 10153...   Gottlieben     TG
# 1  MULTIPOLYGON (((1009842.472 6047985.189, 10097...   Salenstein     TG
# 2  MULTIPOLYGON (((1003037.893 6024982.034, 10030...       Lommis     TG
# 3  MULTIPOLYGON (((1015394.782 6051105.977, 10155...   Tägerwilen     TG
# 4  MULTIPOLYGON (((1021087.392 6029203.396, 10211...       Sulgen     TG
#
#    electric_car_share electric_car_share_last_change  solar_potential_usage  \
# 0            0.013274                     31.01.2023               0.036656
# 1            0.029075                     31.01.2023               0.073700
# 2            0.022893                     31.01.2023               0.049937
# 3            0.032820                     31.01.2023               0.108406
# 4            0.018685                     31.01.2023               0.077358
#
#   solar_potential_usage_last_change  renewable_heating_share  \
# 0                        26.07.2022                 0.214286
# 1                        11.07.2022                 0.299163
# 2                        29.08.2022                 0.513317
# 3                        21.12.2022                 0.346047
# 4                        23.09.2022                 0.262990
#
#    renewable_heating_share_coverage renewable_heating_share_last_change
# 0                          0.832000                          04.01.2023
# 1                          0.856098                          28.12.2022
# 2                          0.820913                          04.01.2023
# 3                          0.862295                          27.01.2023
# 4                          0.851781                          16.02.2023
